# %% [markdown]
# #Applying Batch Gd on multiple input rows

# %% [markdown]
# #First we are calculating  actual coef_ and Intercept_ via sklearn then applying own class

# %%
#importing Libraries and using diabetes dataset
from sklearn.datasets import load_diabetes
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
X,y=load_diabetes(return_X_y=True)

# %%
print(X.shape)
# Out:
# (442, 10)

# %%
print(y.shape)
# Out:
# (442,)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
reg=LinearRegression()

# %%
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
#finding coefficient and intercept from sklearn  then compare with own
#in dataset we have 10 column so we have 10 values B1,B2,B3....(these are weight of each column)
reg.coef_
# Out:
# array([ -10.0098663 , -239.81564367,  519.84592005,  324.3846455 ,
#        -792.17563855,  476.73902101,  101.04326794,  177.06323767,
#         751.27369956,   67.62669218])

# %%
reg.intercept_
#this is intercept value
# Out:
# np.float64(152.13348416289597)

# %%
#calculating r2_score
y_pred=reg.predict(X_test)

# %%
r2_score(y_test,y_pred)# we will compare our value of r2 score with cladd r2 score
# Out:
# 0.45729681888868934

# %% [markdown]
# #Own class

# %%
from pandas._libs.lib import NoDefault
class GDRegressor:

  def __init__(self,learning_rate=0.01,epochs=10):
    self.coef_=None
    self.intercept=None
    self.lr=learning_rate
    self.epochs=epochs

  def fit(self,X_train,y_train):
    #initialise your coefs
    self.intercept_=0
    self.coef_=np.ones(X_train.shape[1])#Getting the number of cols from shape ka second number

    for i in range(self.epochs):
      #update alll the coef and intecept
      y_hat=np.dot(X_train,self.coef_)+self.intercept_
      intercept_der= -2*np.mean(y_train-y_hat)
      self.intercept_=self.intercept_ -(self.lr*intercept_der)

      coef_der=-2*np.dot((y_train-y_hat),X_train)/X_train.shape[0]
      self.coef_=self.coef_-(self.lr*coef_der)

    print(self.intercept_,self.coef_)




  def predict(self,X_test):
    # this is Y hat means prediction
    return np.dot(X_test,self.coef_)+self.intercept_

# %%
gdr=GDRegressor(epochs=1000,learning_rate=0.5)

# %%
gdr.fit(X_train,y_train)
# Out:
# 152.01351687661833 [  14.38990585 -173.7235727   491.54898524  323.91524824  -39.32648042
#  -116.01061213 -194.04077415  103.38135565  451.63448787   97.57218278]

# %%
y_pred=gdr.predict(X_test)

# %%
#calculating r2_score
r2_score(y_test,y_pred)
# Out:
# 0.4534503034722803
