# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
df.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel("CGPA->")
plt.ylabel("Package (in lpa->)")
plt.show()

# %%
X=df[['cgpa']]
y=df[['package']]

# %%
X
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.4,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[2.80823299]])

# %%
X_test
# Out:
#      cgpa
# 95   6.63
# 15   7.25
# 30   7.36
# 158  5.95
# 128  7.93
# ..    ...
# 113  6.94
# 26   8.31
# 139  7.19
# 100  7.95
# 111  5.42
#
# [80 rows x 1 columns]

# %%
y_test
# Out:
#      package
# 95      2.79
# 15      3.23
# 30      3.26
# 158     3.04
# 128     3.34
# ..       ...
# 113     2.37
# 26      3.42
# 139     2.40
# 100     4.14
# 111     2.25
#
# [80 rows x 1 columns]

# %%
#as we compare the 1st value from X_test and Y_test we get almost correct model gives 2.80823 and give data has 2.79 which nearly equals

# %%
#WE have plot the line which linear regression is following while predicting the value

plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel("CGPA")
plt.ylabel("Package")
# Out:
# Text(0, 0.5, 'Package')

# %%
#We can also find slop of line and intercept which line is making with axis
m=lr.coef_

# %%
#intercept
b=lr.intercept_

# %%
#equation of line
#y=mx+b

#x is input cgpa ans y is predicted package
